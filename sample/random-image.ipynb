# %%
# セル 1: 必要なライブラリのインポート
import numpy as np
import matplotlib.pyplot as plt

# セル 2: ランダム画像を生成
# 0〜1のランダムなRGB画像（高さ100x幅100x3チャネル）
random_image = np.random.rand(100, 100, 3)

# セル 3: 画像を表示
plt.imshow(random_image)
plt.title("Random Image")
plt.axis('off')
plt.show()
